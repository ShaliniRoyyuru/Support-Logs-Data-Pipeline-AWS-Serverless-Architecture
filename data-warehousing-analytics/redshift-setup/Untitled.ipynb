# %%
import pandas as pd

# %%
f = pd.read_parquet("C:/Users/shali/Downloads/run-1787849564181-part-block-0-r-00000-snappy.parquet")
f.head()
# Out:
#     ticket_id        created_at       resolved_at   agent priority  \
# 0  TCK0701000  2025-07-01 00:13                     Sneha   Medium
# 1  TCK0701001  2025-07-01 01:24  2025-07-01 02:47   Kavya   Medium
# 2  TCK0701002  2025-07-01 01:49  2025-07-01 19:25   Rohit      Low
# 3  TCK0701004  2025-07-01 03:03  2025-07-02 11:00  Ananya     High
# 4  TCK0701005  2025-07-01 03:07  2025-07-02 00:35   Arjun     High
#
#    num_interactions   issue_category   channel    status
# 0                 7  Payment Failure      Chat      Open
# 1                 8   Account Locked  Web Form  Resolved
# 2                 3       Bug Report  Web Form  Resolved
# 3                 5       Bug Report      Chat  Resolved
# 4                 1       Bug Report     Email  Resolved

# %%
f.describe()
# Out:
#        num_interactions
# count         27.000000
# mean           4.000000
# std            2.336993
# min            1.000000
# 25%            2.000000
# 50%            4.000000
# 75%            6.000000
# max            8.000000

# %%
dir(f)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__arrow_c_stream__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__dataframe__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__firstlineno__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
# ...

# %%
f.dtypes
# Out:
# ticket_id             str
# created_at            str
# resolved_at           str
# agent                 str
# priority              str
# num_interactions    int32
# issue_category        str
# channel               str
# status                str
# dtype: object

# %%
f.shape
# Out:
# (27, 9)
